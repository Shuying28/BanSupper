# %%
url = 'https://raw.githubusercontent.com/tiansien/UMH/main/VCinsight%20(Msia)%20Sanitized.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Load the data**

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#              name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 0  MjAyMDIwNzkyRA==               2014.0      600000000.0      1.000000e+09
# 1  MjAwNjE1MDYzSA==               2006.0      400000000.0      9.000000e+08
# 2      MTI4NjU1M0E=               2018.0       10000000.0      3.000000e+08
# 3  MjAxOTE2MjM5Vw==               2019.0        6000000.0      3.000000e+08
# 4      MTI2NDc2NFA=               2012.0       70000000.0      3.000000e+08
#
#    last_round_size_c    revenue_c date_of_last_round  fy_end revenue_growh  \
# 0        200000000.0  700000000.0             22-Feb  21-Dec          100%
# 1        100000000.0   80000000.0             21-Aug  21-Dec           22%
# 2         10000000.0      30000.0             21-Oct  20-Dec         2042%
# 3          4000000.0  100000000.0             21-Nov  21-Dec           98%
# 4         30000000.0   20000000.0             22-Sep  21-Dec          171%
#
# ...

# %%
df.tail()
# Out:
#                 name_c  incorporated_date_c  total_funding_c  \
# 2186      MTQ5MzcyMlA=               2022.0         100000.0
# 2187  MjAxOTAxMDI1Nzg0               2019.0              NaN
# 2188      MTQ1MDk1OVU=               2022.0          40000.0
# 2189               NaN                  NaN              NaN
# 2190               NaN                  NaN              NaN
#
#       last_valuation_c  last_round_size_c   revenue_c date_of_last_round  \
# 2186               NaN                NaN         NaN                  -
# 2187               NaN                NaN  10000000.0                  -
# 2188               NaN                NaN         NaN                  -
# 2189               NaN                NaN         NaN                NaN
# 2190               NaN                NaN         NaN                NaN
#
#       fy_end revenue_growh     EBIT_c employee_growth_6 employee_growth_12  \
# 2186       -             -        NaN                 -                  -
# ...

# %%
df.shape
# Out:
# (2191, 19)

# %%
df.describe().T
# T is for transpose
# Out:
#                       count          mean           std           min  \
# incorporated_date_c  2189.0  2.014828e+03  5.499934e+00  1.970000e+03
# total_funding_c      2140.0  1.387912e+06  1.663607e+07  1.000000e+00
# last_valuation_c      285.0  2.130374e+07  8.612340e+07  5.000000e+03
# last_round_size_c     285.0  3.056779e+06  1.363528e+07  1.000000e+03
# revenue_c            1542.0  3.272743e+06  3.455250e+07  1.000000e+00
# EBIT_c               1678.0 -2.311092e+05  6.897936e+06 -1.000000e+08
# num_founders         1897.0  1.633105e+00  9.874318e-01  1.000000e+00
# num_funding_rounds   2189.0  2.037460e-01  6.509483e-01  0.000000e+00
# num_shareholders     2095.0  4.016706e+00  5.852958e+00  1.000000e+00
# min_share            2095.0  3.175780e+01  3.585608e+01  0.000000e+00
# median_share         2095.0  4.274506e+01  3.195092e+01  0.000000e+00
# max_share            2095.0  6.629067e+01  2.479368e+01  4.730000e+00
#
# ...

# %%
df['revenue_growh'].value_counts()
# Out:
# -        1355
# -100%      18
# -6%        12
# 22%        11
# 2%          9
#          ...
# 695%        1
# 1116%       1
# 50%         1
# -90%        1
# 9280%       1
# Name: revenue_growh, Length: 359, dtype: int64

# %%
def convert_growth(x):
    if x == '-':
        return ''
    try:
        x = float(x.strip('%'))
        if abs(x) > 100:
            return 1
        else:
            return 0
    except:
        return ''

df['revenue_growh'] = df['revenue_growh'].apply(convert_growth)
df.head()
# Out:
#              name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 0  MjAyMDIwNzkyRA==               2014.0      600000000.0      1.000000e+09
# 1  MjAwNjE1MDYzSA==               2006.0      400000000.0      9.000000e+08
# 2      MTI4NjU1M0E=               2018.0       10000000.0      3.000000e+08
# 3  MjAxOTE2MjM5Vw==               2019.0        6000000.0      3.000000e+08
# 4      MTI2NDc2NFA=               2012.0       70000000.0      3.000000e+08
#
#    last_round_size_c    revenue_c date_of_last_round  fy_end revenue_growh  \
# 0        200000000.0  700000000.0             22-Feb  21-Dec             0
# 1        100000000.0   80000000.0             21-Aug  21-Dec             0
# 2         10000000.0      30000.0             21-Oct  20-Dec             1
# 3          4000000.0  100000000.0             21-Nov  21-Dec             0
# 4         30000000.0   20000000.0             22-Sep  21-Dec             1
#
# ...

# %%
# Check for missing values
print(df.isnull().sum())

# Check for duplicates
print(df.duplicated().sum())
# Out:
# name_c                    2
# incorporated_date_c       2
# total_funding_c          51
# last_valuation_c       1906
# last_round_size_c      1906
# revenue_c               649
# date_of_last_round        2
# fy_end                    2
# revenue_growh             0
# EBIT_c                  513
# employee_growth_6         2
# employee_growth_12        2
# num_founders            294
# num_funding_rounds        2
# num_shareholders         96
# min_share                96
# median_share             96
# max_share                96
# category                 59
# dtype: int64
# 1

# %%
df['date_of_last_round'].replace('-', np.nan, inplace=True)

# %%
df.head()
# Out:
#              name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 0  MjAyMDIwNzkyRA==               2014.0      600000000.0      1.000000e+09
# 1  MjAwNjE1MDYzSA==               2006.0      400000000.0      9.000000e+08
# 2      MTI4NjU1M0E=               2018.0       10000000.0      3.000000e+08
# 3  MjAxOTE2MjM5Vw==               2019.0        6000000.0      3.000000e+08
# 4      MTI2NDc2NFA=               2012.0       70000000.0      3.000000e+08
#
#    last_round_size_c    revenue_c date_of_last_round  fy_end revenue_growh  \
# 0        200000000.0  700000000.0             22-Feb  21-Dec             0
# 1        100000000.0   80000000.0             21-Aug  21-Dec             0
# 2         10000000.0      30000.0             21-Oct  20-Dec             1
# 3          4000000.0  100000000.0             21-Nov  21-Dec             0
# 4         30000000.0   20000000.0             22-Sep  21-Dec             1
#
# ...

# %%
df['date_of_last_round'] = pd.to_datetime(df['date_of_last_round'], format='%d-%b')

# %%
df['fy_end'] = pd.to_datetime(df['fy_end'], format='%d-%b', errors='coerce')
df.dropna(subset=['fy_end'], inplace=True)

# %%
df.tail()
# Out:
#                 name_c  incorporated_date_c  total_funding_c  \
# 2163      MTI0NzkwNVQ=               2017.0              1.0
# 2165      MTQwNjMyN1c=               2021.0              1.0
# 2176      MTM4MDQ0NVY=               2020.0           2000.0
# 2185  MTk3MDAxMDAwMTcy               1970.0              NaN
# 2187  MjAxOTAxMDI1Nzg0               2019.0              NaN
#
#       last_valuation_c  last_round_size_c    revenue_c date_of_last_round  \
# 2163               NaN                NaN       1000.0                NaT
# 2165               NaN                NaN      50000.0                NaT
# 2176               NaN                NaN      40000.0                NaT
# 2185               NaN                NaN  800000000.0                NaT
# 2187               NaN                NaN   10000000.0                NaT
#
#          fy_end revenue_growh       EBIT_c employee_growth_6  \
# 2163 1900-04-21                   -90000.0                 -
# ...

# %%
df = df[df['incorporated_date_c'] >= 2011.0]

# %%
df.tail()
# Out:
#                 name_c  incorporated_date_c  total_funding_c  \
# 2158      MTIyMjg0Mkg=               2017.0        8000000.0
# 2163      MTI0NzkwNVQ=               2017.0              1.0
# 2165      MTQwNjMyN1c=               2021.0              1.0
# 2176      MTM4MDQ0NVY=               2020.0           2000.0
# 2187  MjAxOTAxMDI1Nzg0               2019.0              NaN
#
#       last_valuation_c  last_round_size_c   revenue_c date_of_last_round  \
# 2158               NaN                NaN    900000.0                NaT
# 2163               NaN                NaN      1000.0                NaT
# 2165               NaN                NaN     50000.0                NaT
# 2176               NaN                NaN     40000.0                NaT
# 2187               NaN                NaN  10000000.0                NaT
#
#          fy_end revenue_growh     EBIT_c employee_growth_6 employee_growth_12  \
# ...

# %%
# Drop rows with any NaN or - or empty values
dp =df.dropna(subset=df.columns, how='any', inplace=True)

# %%
df.tail()
# Out:
#            name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 277  MTMxMjg2NVQ=               2019.0         400000.0          400000.0
# 279  MTE4MTk2OFQ=               2016.0         300000.0          300000.0
# 280  MTA1NzMxMFA=               2013.0         300000.0          300000.0
# 281  MTIzNjgzOFQ=               2017.0         200000.0          200000.0
# 282  MTE0MTkwMkQ=               2015.0        2000000.0           40000.0
#
#      last_round_size_c  revenue_c date_of_last_round     fy_end revenue_growh  \
# 277           200000.0   600000.0         1900-03-22 1900-06-21             1
# 279           300000.0   400000.0         1900-06-18 1900-12-20             0
# 280           200000.0  1000000.0         1900-12-18 1900-12-20             0
# 281           200000.0  2000000.0         1900-07-22 1900-12-21             1
# 282            30000.0    80000.0         1900-06-15 1900-06-21             0
#
# ...

# %%
import numpy as np

# replace all "-" with NaN
dp = df.replace("-", np.nan, inplace=True)
dp = df.replace("", np.nan, inplace=True)

# drop all rows with any NaN values
df.dropna(inplace=True)

# %%
df.tail()
# Out:
#            name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 264  OTM0MzU1VA==               2011.0         500000.0          600000.0
# 265  MTI3MTg1MFQ=               2018.0         300000.0          600000.0
# 274  MTIxNDkxOEg=               2017.0         400000.0          400000.0
# 277  MTMxMjg2NVQ=               2019.0         400000.0          400000.0
# 281  MTIzNjgzOFQ=               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c date_of_last_round     fy_end  \
# 264            60000.0  2000000.0         1900-12-19 1900-12-21
# 265           100000.0    50000.0         1900-10-21 1900-06-21
# 274           100000.0  3000000.0         1900-07-21 1900-12-21
# 277           200000.0   600000.0         1900-03-22 1900-06-21
# 281           200000.0  2000000.0         1900-07-22 1900-12-21
#
#      revenue_growh    EBIT_c employee_growth_6 employee_growth_12  \
# ...

# %%
# df['incorporated_date_c'] = pd.to_datetime(df['incorporated_date_c'])
# df['incorporated_date_c'] = df['incorporated_date_c'].dt.year.astype(str)

# %%
df.tail()
# Out:
#            name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 264  OTM0MzU1VA==               2011.0         500000.0          600000.0
# 265  MTI3MTg1MFQ=               2018.0         300000.0          600000.0
# 274  MTIxNDkxOEg=               2017.0         400000.0          400000.0
# 277  MTMxMjg2NVQ=               2019.0         400000.0          400000.0
# 281  MTIzNjgzOFQ=               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c date_of_last_round     fy_end  \
# 264            60000.0  2000000.0         1900-12-19 1900-12-21
# 265           100000.0    50000.0         1900-10-21 1900-06-21
# 274           100000.0  3000000.0         1900-07-21 1900-12-21
# 277           200000.0   600000.0         1900-03-22 1900-06-21
# 281           200000.0  2000000.0         1900-07-22 1900-12-21
#
#      revenue_growh    EBIT_c employee_growth_6 employee_growth_12  \
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.tail()
# Out:
#            name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 264  OTM0MzU1VA==               2011.0         500000.0          600000.0
# 265  MTI3MTg1MFQ=               2018.0         300000.0          600000.0
# 274  MTIxNDkxOEg=               2017.0         400000.0          400000.0
# 277  MTMxMjg2NVQ=               2019.0         400000.0          400000.0
# 281  MTIzNjgzOFQ=               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c date_of_last_round     fy_end  \
# 264            60000.0  2000000.0         1900-12-19 1900-12-21
# 265           100000.0    50000.0         1900-10-21 1900-06-21
# 274           100000.0  3000000.0         1900-07-21 1900-12-21
# 277           200000.0   600000.0         1900-03-22 1900-06-21
# 281           200000.0  2000000.0         1900-07-22 1900-12-21
#
#      revenue_growh    EBIT_c employee_growth_6 employee_growth_12  \
# ...

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# %%
# import pandas as pd


# # create a new DataFrame with the one-hot encoded 'category' column
# dummies = df['category'].str.get_dummies(',|').add_prefix('cat_')

# # convert the one-hot encoded column to the desired format
# encoded = [list(dummies.iloc[i]) for i in range(len(dummies))]

# # replace the 'category' column in the original DataFrame with the encoded version
# df['category'] = encoded

# %%
# import pandas as pd
# from sklearn.preprocessing import MultiLabelBinarizer

# df['category'] = df['category'].str.split(',|')

# mlb = MultiLabelBinarizer()

# df_category = pd.DataFrame(mlb.fit_transform(df['category']), columns=mlb.classes_)

# df = pd.concat([df, df_category], axis=1)

# df.drop(['category'], axis=1, inplace=True)

# %%
df.drop(['category'], axis=1)
# Out:
#                name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 0    MjAyMDIwNzkyRA==               2014.0      600000000.0      1.000000e+09
# 2        MTI4NjU1M0E=               2018.0       10000000.0      3.000000e+08
# 4        MTI2NDc2NFA=               2012.0       70000000.0      3.000000e+08
# 7        RjExMDE5NTRN               2014.0       40000000.0      1.000000e+08
# 10       MTAxNzE1N1Y=               2012.0       10000000.0      9.000000e+07
# ..                ...                  ...              ...               ...
# 264      OTM0MzU1VA==               2011.0         500000.0      6.000000e+05
# 265      MTI3MTg1MFQ=               2018.0         300000.0      6.000000e+05
# 274      MTIxNDkxOEg=               2017.0         400000.0      4.000000e+05
# 277      MTMxMjg2NVQ=               2019.0         400000.0      4.000000e+05
# 281      MTIzNjgzOFQ=               2017.0         200000.0      2.000000e+05
#
# ...

# %%
df.tail()
# Out:
#            name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 264  OTM0MzU1VA==               2011.0         500000.0          600000.0
# 265  MTI3MTg1MFQ=               2018.0         300000.0          600000.0
# 274  MTIxNDkxOEg=               2017.0         400000.0          400000.0
# 277  MTMxMjg2NVQ=               2019.0         400000.0          400000.0
# 281  MTIzNjgzOFQ=               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c date_of_last_round     fy_end  \
# 264            60000.0  2000000.0         1900-12-19 1900-12-21
# 265           100000.0    50000.0         1900-10-21 1900-06-21
# 274           100000.0  3000000.0         1900-07-21 1900-12-21
# 277           200000.0   600000.0         1900-03-22 1900-06-21
# 281           200000.0  2000000.0         1900-07-22 1900-12-21
#
#      revenue_growh    EBIT_c employee_growth_6 employee_growth_12  \
# ...

# %%
df.revenue_growh.unique()
# Out:
# array([0., 1.])

# %%
plt.hist(df['revenue_growh'], color='g')
plt.title('Plot_revenue_growh')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
# Generate and visualize the correlation matrix
corr = df.corr().round(2)

# Mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set figure size
f, ax = plt.subplots(figsize=(20, 20))

# Define custom colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)

plt.tight_layout()

# %%
print(df.columns)
# Out:
# Index(['name_c', 'incorporated_date_c', 'total_funding_c', 'last_valuation_c',
#        'last_round_size_c', 'revenue_c', 'date_of_last_round', 'fy_end',
#        'revenue_growh', 'EBIT_c', 'employee_growth_6', 'employee_growth_12',
#        'num_founders', 'num_funding_rounds', 'num_shareholders', 'min_share',
#        'median_share', 'max_share', 'category'],
#       dtype='object')

# %%
X = df[['name_c', 'incorporated_date_c', 'total_funding_c', 'last_valuation_c',
       'last_round_size_c', 'revenue_c', 'date_of_last_round', 'fy_end',
       'revenue_growh', 'EBIT_c', 'employee_growth_6', 'employee_growth_12',
       'num_founders', 'num_funding_rounds', 'num_shareholders', 'min_share',
       'median_share', 'max_share', 'category']]
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Remove non-numeric columns
X = X.select_dtypes(include=np.number)

# Calculate VIF values for each variable
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# Display VIF table
print(vif)
# Out:
#     VIF Factor             features
# 0    43.424445  incorporated_date_c
# 1   111.306365      total_funding_c
# 2    14.406120     last_valuation_c
# 3   143.762846    last_round_size_c
# 4    36.346233            revenue_c
# 5     1.694304        revenue_growh
# 6    74.391770               EBIT_c
# 7     6.262177         num_founders
# 8     7.582916   num_funding_rounds
# 9     5.962867     num_shareholders
# 10   29.372294            min_share
# 11   36.391747         median_share
# 12   11.400732            max_share

# %%
df.head()
# Out:
#               name_c  incorporated_date_c  total_funding_c  last_valuation_c  \
# 0   MjAyMDIwNzkyRA==               2014.0      600000000.0      1.000000e+09
# 2       MTI4NjU1M0E=               2018.0       10000000.0      3.000000e+08
# 4       MTI2NDc2NFA=               2012.0       70000000.0      3.000000e+08
# 7       RjExMDE5NTRN               2014.0       40000000.0      1.000000e+08
# 10      MTAxNzE1N1Y=               2012.0       10000000.0      9.000000e+07
#
#     last_round_size_c    revenue_c date_of_last_round     fy_end  \
# 0         200000000.0  700000000.0         1900-02-22 1900-12-21
# 2          10000000.0      30000.0         1900-10-21 1900-12-20
# 4          30000000.0   20000000.0         1900-09-22 1900-12-21
# 7          20000000.0  700000000.0         1900-12-19 1900-12-21
# 10         10000000.0   10000000.0         1900-02-23 1900-12-21
#
#     revenue_growh       EBIT_c employee_growth_6 employee_growth_12  \
# ...

# %%
df = df.drop(['name_c'], axis=1)
df = df.drop(['date_of_last_round'], axis=1)
df = df.drop(['fy_end'], axis=1)

# %%
df.head()
# Out:
#     incorporated_date_c  total_funding_c  last_valuation_c  last_round_size_c  \
# 0                2014.0      600000000.0      1.000000e+09        200000000.0
# 2                2018.0       10000000.0      3.000000e+08         10000000.0
# 4                2012.0       70000000.0      3.000000e+08         30000000.0
# 7                2014.0       40000000.0      1.000000e+08         20000000.0
# 10               2012.0       10000000.0      9.000000e+07         10000000.0
#
#       revenue_c  revenue_growh       EBIT_c employee_growth_6  \
# 0   700000000.0            0.0 -100000000.0               -1%
# 2       30000.0            1.0   -5000000.0              -18%
# 4    20000000.0            1.0   -9000000.0               -4%
# 7   700000000.0            0.0  -60000000.0                3%
# 10   10000000.0            0.0     400000.0                8%
#
#    employee_growth_12  num_founders  num_funding_rounds  num_shareholders  \
# ...

# %%
# # df = df.drop(['employee_growth_12'], axis=1)
# df['employee_growth_12'] = df['employee_growth_12'].astype(float).round(2)
# df['employee_growth_12'] = df['employee_growth_12'].apply(lambda x: round(float(x), 2))
# df = df.drop(['employee_growth_6'], axis=1)

# %%
df['employee_growth_12'] = df['employee_growth_12'].str.replace('%', '').astype(float) / 100
df['employee_growth_6'] = df['employee_growth_6'].str.replace('%', '').astype(float) / 100

# %%
df.tail()
# Out:
#      incorporated_date_c  total_funding_c  last_valuation_c  \
# 262               2015.0         700000.0          700000.0
# 265               2018.0         300000.0          600000.0
# 274               2017.0         400000.0          400000.0
# 277               2019.0         400000.0          400000.0
# 281               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c  revenue_growh    EBIT_c  employee_growth_6  \
# 262           600000.0  2000000.0            1.0 -800000.0               0.10
# 265           100000.0    50000.0            1.0  -10000.0              -0.03
# 274           100000.0  3000000.0            0.0 -100000.0              -0.08
# 277           200000.0   600000.0            1.0   -4000.0               0.21
# 281           200000.0  2000000.0            1.0  900000.0               0.08
#
#      employee_growth_12  num_founders  num_funding_rounds  num_shareholders  \
# ...

# %% [markdown]
# # **Building Model**

# %%
# We need to separate it first before train the data
X = df.drop(['revenue_growh'],axis=1)
y = df['revenue_growh']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %%
df.tail()
# Out:
#      incorporated_date_c  total_funding_c  last_valuation_c  \
# 262               2015.0         700000.0          700000.0
# 265               2018.0         300000.0          600000.0
# 274               2017.0         400000.0          400000.0
# 277               2019.0         400000.0          400000.0
# 281               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c  revenue_growh    EBIT_c  employee_growth_6  \
# 262           600000.0  2000000.0            1.0 -800000.0               0.10
# 265           100000.0    50000.0            1.0  -10000.0              -0.03
# 274           100000.0  3000000.0            0.0 -100000.0              -0.08
# 277           200000.0   600000.0            1.0   -4000.0               0.21
# 281           200000.0  2000000.0            1.0  900000.0               0.08
#
#      employee_growth_12  num_founders  num_funding_rounds  num_shareholders  \
# ...

# %% [markdown]
# # ***Feature Scaling***

# %%
df.columns
# Out:
# Index(['incorporated_date_c', 'total_funding_c', 'last_valuation_c',
#        'last_round_size_c', 'revenue_c', 'revenue_growh', 'EBIT_c',
#        'employee_growth_6', 'employee_growth_12', 'num_founders',
#        'num_funding_rounds', 'num_shareholders', 'min_share', 'median_share',
#        'max_share', 'category'],
#       dtype='object')

# %%
df.tail()
# Out:
#      incorporated_date_c  total_funding_c  last_valuation_c  \
# 262               2015.0         700000.0          700000.0
# 265               2018.0         300000.0          600000.0
# 274               2017.0         400000.0          400000.0
# 277               2019.0         400000.0          400000.0
# 281               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c  revenue_growh    EBIT_c  employee_growth_6  \
# 262           600000.0  2000000.0            1.0 -800000.0               0.10
# 265           100000.0    50000.0            1.0  -10000.0              -0.03
# 274           100000.0  3000000.0            0.0 -100000.0              -0.08
# 277           200000.0   600000.0            1.0   -4000.0               0.21
# 281           200000.0  2000000.0            1.0  900000.0               0.08
#
#      employee_growth_12  num_founders  num_funding_rounds  num_shareholders  \
# ...

# %%
df.tail()
# Out:
#      incorporated_date_c  total_funding_c  last_valuation_c  \
# 262               2015.0         700000.0          700000.0
# 265               2018.0         300000.0          600000.0
# 274               2017.0         400000.0          400000.0
# 277               2019.0         400000.0          400000.0
# 281               2017.0         200000.0          200000.0
#
#      last_round_size_c  revenue_c  revenue_growh    EBIT_c  employee_growth_6  \
# 262           600000.0  2000000.0            1.0 -800000.0               0.10
# 265           100000.0    50000.0            1.0  -10000.0              -0.03
# 274           100000.0  3000000.0            0.0 -100000.0              -0.08
# 277           200000.0   600000.0            1.0   -4000.0               0.21
# 281           200000.0  2000000.0            1.0  900000.0               0.08
#
#      employee_growth_12  num_founders  num_funding_rounds  num_shareholders  \
# ...

# %% [markdown]
# # **Models and finding out the Best one**

# %% [markdown]
# **Logistic Regression**

# %%
print(X_train.dtypes)
print()
print(y_train.dtypes)
print(y_train)
# Out:
# incorporated_date_c    float64
# total_funding_c        float64
# last_valuation_c       float64
# last_round_size_c      float64
# revenue_c              float64
# EBIT_c                 float64
# employee_growth_6      float64
# employee_growth_12     float64
# num_founders           float64
# num_funding_rounds     float64
# num_shareholders       float64
# min_share              float64
# median_share           float64
# max_share              float64
# category                object
# dtype: object
#
# float64
# 130    0.0
# 221    0.0
# 197    0.0
# 0      0.0
# 93     1.0
#       ...
# 115    1.0
# 79     0.0
# 14     0.0
# 234    0.0
# 149    1.0
# Name: revenue_growh, Length: 72, dtype: float64

# %%
X_train = X_train.drop(['category'], axis=1)
# X_train = X_train.drop(['employee_growth_12'], axis=1)

# %%
print(X_train.dtypes)
print()
print(y_train.dtypes)
print(y_train)
# Out:
# incorporated_date_c    float64
# total_funding_c        float64
# last_valuation_c       float64
# last_round_size_c      float64
# revenue_c              float64
# EBIT_c                 float64
# employee_growth_6      float64
# employee_growth_12     float64
# num_founders           float64
# num_funding_rounds     float64
# num_shareholders       float64
# min_share              float64
# median_share           float64
# max_share              float64
# dtype: object
#
# float64
# 130    0.0
# 221    0.0
# 197    0.0
# 0      0.0
# 93     1.0
#       ...
# 115    1.0
# 79     0.0
# 14     0.0
# 234    0.0
# 149    1.0
# Name: revenue_growh, Length: 72, dtype: float64

# %%
X_test = X_test[X_train.columns]

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
model1 = lr.fit(X_train, y_train)
prediction1 = model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[18,  2],
#        [ 9,  2]])

# %%
sns.heatmap(cm,annot=True)
plt.savefig('h.png')

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy: 0.6363636363636364

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction1)
# Out:
# 0.6363636363636364

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[17,  6],
#        [ 2,  8]])

# %%
accuracy_score(y_test,prediction2)
# Out:
# 0.7575757575757576

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[21,  2],
#        [ 6,  4]])

# %%
accuracy_score(y_test, prediction3)
# Out:
# 0.7575757575757576

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.91      0.84        23
#          1.0       0.67      0.40      0.50        10
#
#     accuracy                           0.76        33
#    macro avg       0.72      0.66      0.67        33
# weighted avg       0.74      0.76      0.74        33

# %%
print(classification_report(y_test, prediction1))

print(classification_report(y_test, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.83      0.76        23
#          1.0       0.33      0.20      0.25        10
#
#     accuracy                           0.64        33
#    macro avg       0.52      0.51      0.51        33
# weighted avg       0.59      0.64      0.61        33
#
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.74      0.81        23
#          1.0       0.57      0.80      0.67        10
#
#     accuracy                           0.76        33
#    macro avg       0.73      0.77      0.74        33
# weighted avg       0.80      0.76      0.77        33

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# predict class labels for test set
y_pred = model3.predict(X_test)

# create confusion matrix
conf_mat = confusion_matrix(y_test, y_pred)

# plot confusion matrix using heatmap
sns.heatmap(conf_mat, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import mean_squared_error
# from sklearn.model_selection import train_test_split
# import pandas as pd


# # # Split the dataset into training and testing sets
# # X_train, X_test, y_train, y_test = train_test_split(data.drop("target", axis=1), data["target"], test_size=0.2)

# # Train a random forest regression model
# model = RandomForestRegressor(n_estimators=100, max_depth=5)
# model.fit(X_train, y_train)

# # Make predictions on the testing set
# y_pred = model.predict(X_test)

# # Evaluate the performance of the model using mean squared error
# mse = mean_squared_error(y_test, y_pred)
# print("Mean Squared Error:", mse)

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt

# predict class probabilities for test set
y_prob = model3.predict_proba(X_test)[:, 1]

# create ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# plot ROC curve
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# # # Create a random forest model
# # rf = RandomForestRegressor(n_estimators=100, random_state=42)

# # # Fit the model to the training data
# # rf.fit(X_train, y_train)

# # # Make predictions on the test data
# # y_pred = rf.predict(X_test)

# # Calculate R-squared
# r2 = r2_score(y_test, y_pred)

# # Calculate MAE
# mae = mean_absolute_error(y_test, y_pred)

# # Calculate RMSE
# mse = mean_squared_error(y_test, y_pred)
# rmse = mse ** 0.5

# # Print the results
# print("R-squared: {:.2f}".format(r2))
# print("MAE: {:.2f}".format(mae))
# print("RMSE: {:.2f}".format(rmse))

# %% [markdown]
# **K Nearest Neighbor (K NN) Support Vector Machine Naive Bayes**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
models=[]

models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# evaluate each model

results =[]
names=[]
for name , model in models:
    kfold=KFold(n_splits=10, shuffle=True, random_state=40)
    cv_results= cross_val_score(model, X_train, y_train, cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    
    msg= '%s:, %f, (%f)' % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# KNN:, 0.489286, (0.186297)
# NB:, 0.319643, (0.126886)
# SVM:, 0.683929, (0.176425)

# %%
# make predictions on validation datasets

SVM = SVC()
SVM.fit(X_train, y_train)
predictions= SVM.predict(X_test)
print(accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 0.6774193548387096
#               precision    recall  f1-score   support
#
#          0.0       0.67      1.00      0.80        20
#          1.0       1.00      0.09      0.17        11
#
#     accuracy                           0.68        31
#    macro avg       0.83      0.55      0.48        31
# weighted avg       0.78      0.68      0.58        31
#
# [[20  0]
#  [10  1]]
