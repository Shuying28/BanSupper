# %%
url = 'https://raw.githubusercontent.com/tiansien/UMH/main/startup%20data.csv'

# %% [markdown]
# # **Import Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Load the data**

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 0        1005         CA  42.358880  -71.056820    92101   c:6669
# 1         204         CA  37.238916 -121.973718    95032  c:16283
# 2        1001         CA  32.901049 -117.192656    92121  c:65620
# 3         738         CA  37.320309 -122.050040    95014  c:42668
# 4        1002         CA  37.779281 -122.419236    94105  c:65806
#
#             city              Unnamed: 6               name  labels  ...  \
# 0      San Diego                     NaN        Bandsintown       1  ...
# 1      Los Gatos                     NaN          TriCipher       1  ...
# 2      San Diego      San Diego CA 92121              Plixi       1  ...
# 3      Cupertino      Cupertino CA 95014  Solidcore Systems       1  ...
# 4  San Francisco  San Francisco CA 94105     Inhale Digital       0  ...
#
#   object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0 state_code   latitude   longitude zip_code       id  \
# 918         352         CA  37.740594 -122.376471    94107  c:21343
# 919         721         MA  42.504817  -71.195611     1803  c:41747
# 920         557         CA  37.408261 -122.015920    94089  c:31549
# 921         589         CA  37.556732 -122.288378    94404  c:33198
# 922         462         CA  37.386778 -121.966277    95054  c:26702
#
#               city            Unnamed: 6                  name  labels  ...  \
# 918  San Francisco                   NaN               CoTweet       1  ...
# 919     Burlington    Burlington MA 1803    Reef Point Systems       0  ...
# 920      Sunnyvale                   NaN       Paracor Medical       0  ...
# 921  San Francisco                   NaN               Causata       1  ...
# 922    Santa Clara  Santa Clara CA 95054  Asempra Technologies       1  ...
#
#     object_id has_VC has_angel has_roundA  has_roundB  has_roundC  has_roundD  \
# ...

# %%
df.shape
# Out:
# (923, 49)

# %%
df.describe().T
# T is for transpose
# Out:
#                           count          mean           std           min  \
# Unnamed: 0                923.0  5.722979e+02  3.335854e+02      1.000000
# latitude                  923.0  3.851744e+01  3.741497e+00     25.752358
# longitude                 923.0 -1.035392e+02  2.239417e+01   -122.756956
# labels                    923.0  6.468039e-01  4.782221e-01      0.000000
# age_first_funding_year    923.0  2.235630e+00  2.510449e+00     -9.046600
# age_last_funding_year     923.0  3.931456e+00  2.967910e+00     -9.046600
# age_first_milestone_year  771.0  3.055353e+00  2.977057e+00    -14.169900
# age_last_milestone_year   771.0  4.754423e+00  3.212107e+00     -7.005500
# relationships             923.0  7.710726e+00  7.265776e+00      0.000000
# funding_rounds            923.0  2.310943e+00  1.390922e+00      1.000000
# funding_total_usd         923.0  2.541975e+07  1.896344e+08  11000.000000
# milestones                923.0  1.841820e+00  1.322632e+00      0.000000
# ...

# %%
df.labels.unique()
# Out:
# array([1, 0])

# %%
df['labels'].value_counts()
# Out:
# 1    597
# 0    326
# Name: labels, dtype: int64

# %%
sns.countplot(data=df, x='labels')
# Out:
# <Axes: xlabel='labels', ylabel='count'>

# %% [markdown]
# # **Clean and prepare the data**

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.drop('name',axis=1,inplace=True)
df.drop('id',axis=1,inplace=True)
df.drop('Unnamed: 6',axis=1,inplace=True)
df.drop('object_id',axis=1,inplace=True)

# %%
df.head()
# Out:
#   state_code   latitude   longitude zip_code           city  labels  \
# 0         CA  42.358880  -71.056820    92101      San Diego       1
# 1         CA  37.238916 -121.973718    95032      Los Gatos       1
# 2         CA  32.901049 -117.192656    92121      San Diego       1
# 3         CA  37.320309 -122.050040    95014      Cupertino       1
# 4         CA  37.779281 -122.419236    94105  San Francisco       0
#
#   founded_at  closed_at first_funding_at last_funding_at  ...  \
# 0   1/1/2007        NaN         4/1/2009        1/1/2010  ...
# 1   1/1/2000        NaN        2/14/2005      12/28/2009  ...
# 2  3/18/2009        NaN        3/30/2010       3/30/2010  ...
# 3   1/1/2002        NaN        2/17/2005       4/25/2007  ...
# 4   8/1/2010  10/1/2012         8/1/2010        4/1/2012  ...
#
#    is_othercategory  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 0                 1       0          1           0           0           0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
le = LabelEncoder()

# fit the LabelEncoder to the state_code column and transform the values
df['state_code'] = le.fit_transform(df['state_code'])

# display the label and the corresponding numerical values
print("Label Encoding:")
for i, label in enumerate(le.classes_):
    print(f"{label} -> {i}")
# Out:
# Label Encoding:
# AR -> 0
# AZ -> 1
# CA -> 2
# CO -> 3
# CT -> 4
# DC -> 5
# FL -> 6
# GA -> 7
# ID -> 8
# IL -> 9
# IN -> 10
# KY -> 11
# MA -> 12
# MD -> 13
# ME -> 14
# MI -> 15
# MN -> 16
# MO -> 17
# NC -> 18
# NH -> 19
# NJ -> 20
# NM -> 21
# NV -> 22
# NY -> 23
# OH -> 24
# OR -> 25
# PA -> 26
# RI -> 27
# TN -> 28
# TX -> 29
# UT -> 30
# VA -> 31
# WA -> 32
# WI -> 33
# WV -> 34

# %%
df.head()
# Out:
#    state_code   latitude   longitude zip_code           city  labels  \
# 0           2  42.358880  -71.056820    92101      San Diego       1
# 1           2  37.238916 -121.973718    95032      Los Gatos       1
# 2           2  32.901049 -117.192656    92121      San Diego       1
# 3           2  37.320309 -122.050040    95014      Cupertino       1
# 4           2  37.779281 -122.419236    94105  San Francisco       0
#
#   founded_at  closed_at first_funding_at last_funding_at  ...  \
# 0   1/1/2007        NaN         4/1/2009        1/1/2010  ...
# 1   1/1/2000        NaN        2/14/2005      12/28/2009  ...
# 2  3/18/2009        NaN        3/30/2010       3/30/2010  ...
# 3   1/1/2002        NaN        2/17/2005       4/25/2007  ...
# 4   8/1/2010  10/1/2012         8/1/2010        4/1/2012  ...
#
#    is_othercategory  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 0                 1       0          1           0           0           0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
le = LabelEncoder()

# fit the LabelEncoder to the state_code column and transform the values
df['status'] = le.fit_transform(df['status'])

# display the label and the corresponding numerical values
print("Label Encoding:")
for i, label in enumerate(le.classes_):
    print(f"{label} -> {i}")
# Out:
# Label Encoding:
# acquired -> 0
# closed -> 1

# %%
df.head()
# Out:
#    state_code   latitude   longitude zip_code           city  labels  \
# 0           2  42.358880  -71.056820    92101      San Diego       1
# 1           2  37.238916 -121.973718    95032      Los Gatos       1
# 2           2  32.901049 -117.192656    92121      San Diego       1
# 3           2  37.320309 -122.050040    95014      Cupertino       1
# 4           2  37.779281 -122.419236    94105  San Francisco       0
#
#   founded_at  closed_at first_funding_at last_funding_at  ...  \
# 0   1/1/2007        NaN         4/1/2009        1/1/2010  ...
# 1   1/1/2000        NaN        2/14/2005      12/28/2009  ...
# 2  3/18/2009        NaN        3/30/2010       3/30/2010  ...
# 3   1/1/2002        NaN        2/17/2005       4/25/2007  ...
# 4   8/1/2010  10/1/2012         8/1/2010        4/1/2012  ...
#
#    is_othercategory  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 0                 1       0          1           0           0           0
# ...

# %%
df.columns
# Out:
# Index(['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'labels',
#        'founded_at', 'closed_at', 'first_funding_at', 'last_funding_at',
#        'age_first_funding_year', 'age_last_funding_year',
#        'age_first_milestone_year', 'age_last_milestone_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'state_code.1',
#        'is_CA', 'is_NY', 'is_MA', 'is_TX', 'is_otherstate', 'category_code',
#        'is_software', 'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status'],
#       dtype='object')

# %%
# df.drop('status',axis=1,inplace=True)

# %%
df.head()
# Out:
#    state_code   latitude   longitude zip_code           city  labels  \
# 0           2  42.358880  -71.056820    92101      San Diego       1
# 1           2  37.238916 -121.973718    95032      Los Gatos       1
# 2           2  32.901049 -117.192656    92121      San Diego       1
# 3           2  37.320309 -122.050040    95014      Cupertino       1
# 4           2  37.779281 -122.419236    94105  San Francisco       0
#
#   founded_at  closed_at first_funding_at last_funding_at  ...  \
# 0   1/1/2007        NaN         4/1/2009        1/1/2010  ...
# 1   1/1/2000        NaN        2/14/2005      12/28/2009  ...
# 2  3/18/2009        NaN        3/30/2010       3/30/2010  ...
# 3   1/1/2002        NaN        2/17/2005       4/25/2007  ...
# 4   8/1/2010  10/1/2012         8/1/2010        4/1/2012  ...
#
#    is_othercategory  has_VC  has_angel  has_roundA  has_roundB  has_roundC  \
# 0                 1       0          1           0           0           0
# ...

# %%
df.drop('first_funding_at',axis=1,inplace=True)
df.drop('last_funding_at',axis=1,inplace=True)
df.drop('closed_at',axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
le = LabelEncoder()

# fit the LabelEncoder to the state_code column and transform the values
df['city'] = le.fit_transform(df['city'])

# display the label and the corresponding numerical values
print("Label Encoding:")
for i, label in enumerate(le.classes_):
    print(f"{label} -> {i}")
# Out:
# Label Encoding:
# Acton -> 0
# Addison -> 1
# Alameda -> 2
# Albuquerque -> 3
# Aliso Viejo -> 4
# Allentown -> 5
# Alpharetta -> 6
# Altamonte Springs -> 7
# Andover -> 8
# Annapolis -> 9
# Arcadia -> 10
# Arlington -> 11
# Atlanta -> 12
# Austin -> 13
# Avon -> 14
# Bala Cynwyd -> 15
# Bedford -> 16
# Bellevue -> 17
# Belmont -> 18
# Berkeley -> 19
# Berwyn -> 20
# Bethesda -> 21
# Bethlehem -> 22
# Beverly Hills -> 23
# Billerica -> 24
# Bingham Farms -> 25
# Bloomfield -> 26
# Boston -> 27
# Bothell -> 28
# Boulder -> 29
# Boxborough -> 30
# Brisbane -> 31
# Brooklyn -> 32
# Broomfield -> 33
# Burlingame -> 34
# Burlington -> 35
# Calabasas -> 36
# Cambridge -> 37
# Campbell -> 38
# Canton -> 39
# Carlsbad -> 40
# Carpinteria -> 41
# Centennial -> 42
# Champaign -> 43
# Chantilly -> 44
# Charlottesville -> 45
# Chelmsford -> 46
# Chevy Chase -> 47
# Chicago -> 48
# Cincinnati -> 49
# Cleveland -> 50
# College Park -> 51
# Columbia -> 52
# Columbus -> 53
# Conshohocken -> 54
# ...

# %%
df.head()
# Out:
#    state_code   latitude   longitude zip_code  city  labels founded_at  \
# 0           2  42.358880  -71.056820    92101   173       1   1/1/2007
# 1           2  37.238916 -121.973718    95032   108       1   1/1/2000
# 2           2  32.901049 -117.192656    92121   173       1  3/18/2009
# 3           2  37.320309 -122.050040    95014    55       1   1/1/2002
# 4           2  37.779281 -122.419236    94105   174       0   8/1/2010
#
#    age_first_funding_year  age_last_funding_year  age_first_milestone_year  \
# 0                  2.2493                 3.0027                    4.6685
# 1                  5.1260                 9.9973                    7.0055
# 2                  1.0329                 1.0329                    1.4575
# 3                  3.1315                 5.3151                    6.0027
# 4                  0.0000                 1.6685                    0.0384
#
#    ...  is_othercategory  has_VC  has_angel  has_roundA  has_roundB  \
# ...

# %%
# # convert the founded_at column to datetime format
# df['founded_at'] = pd.to_datetime(df['founded_at'], format='%m/%d/%Y')

# # filter the DataFrame to keep only rows with founded_at value on or after January 1st, 2013
# df = df[df['founded_at'] >= '2013-01-01']

# %%
df.drop('founded_at',axis=1,inplace=True)

# %%
df.tail()
# Out:
#      state_code   latitude   longitude zip_code  city  labels  \
# 918           2  37.740594 -122.376471    94107   174       1
# 919          12  42.504817  -71.195611     1803    35       0
# 920           2  37.408261 -122.015920    94089   191       0
# 921           2  37.556732 -122.288378    94404   174       1
# 922           2  37.386778 -121.966277    95054   181       1
#
#      age_first_funding_year  age_last_funding_year  age_first_milestone_year  \
# 918                  0.5178                 0.5178                    0.5808
# 919                  7.2521                 9.2274                    6.0027
# 920                  8.4959                 8.4959                    9.0055
# 921                  0.7589                 2.8329                    0.7589
# 922                  3.1205                 3.1205                    4.0027
#
#      age_last_milestone_year  ...  is_othercategory  has_VC  has_angel  \
# ...

# %%
# drop columns containing NaN values
df = df.dropna(axis=1)

# print the updated DataFrame
df.tail()
# Out:
#      state_code   latitude   longitude zip_code  city  labels  \
# 918           2  37.740594 -122.376471    94107   174       1
# 919          12  42.504817  -71.195611     1803    35       0
# 920           2  37.408261 -122.015920    94089   191       0
# 921           2  37.556732 -122.288378    94404   174       1
# 922           2  37.386778 -121.966277    95054   181       1
#
#      age_first_funding_year  age_last_funding_year  relationships  \
# 918                  0.5178                 0.5178              9
# 919                  7.2521                 9.2274              1
# 920                  8.4959                 8.4959              5
# 921                  0.7589                 2.8329             12
# 922                  3.1205                 3.1205              4
#
#      funding_rounds  ...  is_othercategory  has_VC  has_angel  has_roundA  \
# 918               1  ...                 0       0          0           1
# ...

# %%
df.columns
# Out:
# Index(['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'labels',
#        'age_first_funding_year', 'age_last_funding_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status'],
#       dtype='object')

# %%
# from sklearn.preprocessing import LabelEncoder

# # create an instance of LabelEncoder
# le = LabelEncoder()

# # fit the LabelEncoder to the state_code column and transform the values
# df['state_code.1'] = le.fit_transform(df['state_code.1'])

# # display the label and the corresponding numerical values
# print("Label Encoding:")
# for i, label in enumerate(le.classes_):
#     print(f"{label} -> {i}")

# %%
from sklearn.preprocessing import LabelEncoder

# create an instance of LabelEncoder
le = LabelEncoder()

# fit the LabelEncoder to the state_code column and transform the values
df['category_code'] = le.fit_transform(df['category_code'])

# display the label and the corresponding numerical values
print("Label Encoding:")
for i, label in enumerate(le.classes_):
    print(f"{label} -> {i}")
# Out:
# Label Encoding:
# advertising -> 0
# analytics -> 1
# automotive -> 2
# biotech -> 3
# cleantech -> 4
# consulting -> 5
# ecommerce -> 6
# education -> 7
# enterprise -> 8
# fashion -> 9
# finance -> 10
# games_video -> 11
# hardware -> 12
# health -> 13
# hospitality -> 14
# manufacturing -> 15
# medical -> 16
# messaging -> 17
# mobile -> 18
# music -> 19
# network_hosting -> 20
# news -> 21
# other -> 22
# photo_video -> 23
# public_relations -> 24
# real_estate -> 25
# search -> 26
# security -> 27
# semiconductor -> 28
# social -> 29
# software -> 30
# sports -> 31
# transportation -> 32
# travel -> 33
# web -> 34

# %%
df.isnull().sum()
# Out:
# state_code                0
# latitude                  0
# longitude                 0
# zip_code                  0
# city                      0
# labels                    0
# age_first_funding_year    0
# age_last_funding_year     0
# relationships             0
# funding_rounds            0
# funding_total_usd         0
# milestones                0
# is_CA                     0
# is_NY                     0
# is_MA                     0
# is_TX                     0
# is_otherstate             0
# category_code             0
# is_software               0
# is_web                    0
# is_mobile                 0
# is_enterprise             0
# is_advertising            0
# is_gamesvideo             0
# is_ecommerce              0
# is_biotech                0
# is_consulting             0
# is_othercategory          0
# has_VC                    0
# has_angel                 0
# has_roundA                0
# has_roundB                0
# has_roundC                0
# ...

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
df = df.drop_duplicates()

# %%
df.corr()
# important to check there're two reletion between
# Out:
#                         state_code  latitude  longitude      city    labels  \
# state_code                1.000000  0.346402   0.553604 -0.217044 -0.078341
# latitude                  0.346402  1.000000   0.368475  0.035419  0.046560
# longitude                 0.553604  0.368475   1.000000 -0.274929 -0.036092
# city                     -0.217044  0.035419  -0.274929  1.000000  0.000424
# labels                   -0.078341  0.046560  -0.036092  0.000424  1.000000
# age_first_funding_year   -0.044123 -0.046868  -0.014158 -0.037569 -0.075637
# age_last_funding_year    -0.076780 -0.041692  -0.000148 -0.075503  0.073731
# relationships            -0.091086 -0.039198  -0.073197  0.053883  0.360434
# funding_rounds           -0.042807 -0.000659   0.022447 -0.077718  0.206049
# funding_total_usd         0.051226 -0.072941   0.017970 -0.027347  0.040176
# milestones               -0.019175  0.017708  -0.016420  0.012072  0.328260
# ...

# %%
plt.hist(df['labels'], color='g')
plt.title('Plot_labels')
plt.show()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.columns.is_floating
# Out:
# <bound method Index.is_floating of Index(['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'labels',
#        'age_first_funding_year', 'age_last_funding_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status'],
#       dtype='object')>

# %%
df.columns
# Out:
# Index(['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'labels',
#        'age_first_funding_year', 'age_last_funding_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status'],
#       dtype='object')

# %%
df = df[~df['zip_code'].str.contains('-')]

# %%
df = df.drop('zip_code', axis=1)

# %%
# X = df[['state_code', 'latitude', 'longitude', 'zip_code', 'city', 'labels',
#        'age_first_funding_year', 'age_last_funding_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status']]

# # Calculate VIF values for each variable
# vif = pd.DataFrame()
# vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
# vif["features"] = X.columns

# # Display VIF table
# print(vif)

# %%
# Draw the heatmap again, with the new correlation matrix
from statsmodels.stats.outliers_influence import variance_inflation_factor
corr = df.corr().round(2)
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.color_palette('coolwarm', as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmin=-1, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True)
plt.tight_layout()

# %%
df.columns
# Out:
# Index(['state_code', 'latitude', 'longitude', 'city', 'labels',
#        'age_first_funding_year', 'age_last_funding_year', 'relationships',
#        'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
#        'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
#        'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
#        'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
#        'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
#        'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status'],
#       dtype='object')

# %%
X = df[['state_code', 'latitude', 'longitude', 'city', 'labels',
       'age_first_funding_year', 'age_last_funding_year', 'relationships',
       'funding_rounds', 'funding_total_usd', 'milestones', 'is_CA', 'is_NY',
       'is_MA', 'is_TX', 'is_otherstate', 'category_code', 'is_software',
       'is_web', 'is_mobile', 'is_enterprise', 'is_advertising',
       'is_gamesvideo', 'is_ecommerce', 'is_biotech', 'is_consulting',
       'is_othercategory', 'has_VC', 'has_angel', 'has_roundA', 'has_roundB',
       'has_roundC', 'has_roundD', 'avg_participants', 'is_top500', 'status']]

# Remove non-numeric columns
X = X.select_dtypes(include=np.number)

# Calculate VIF values for each variable
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# Display VIF table
print(vif)
# Out:
#       VIF Factor                features
# 0   5.554794e+00              state_code
# 1   2.351375e+00                latitude
# 2   3.584461e+00               longitude
# 3   1.372520e+00                    city
# 4            inf                  labels
# 5   6.374432e+00  age_first_funding_year
# 6   7.527942e+00   age_last_funding_year
# 7   1.731847e+00           relationships
# 8   3.805900e+00          funding_rounds
# 9   1.113594e+00       funding_total_usd
# 10  1.703039e+00              milestones
# 11  2.299657e+02                   is_CA
# 12  1.003802e+02                   is_NY
# 13  7.745460e+01                   is_MA
# 14  4.459053e+01                   is_TX
# 15  1.642549e+02           is_otherstate
# 16  5.194151e+00           category_code
# 17           inf             is_software
# 18           inf                  is_web
# 19           inf               is_mobile
# 20           inf           is_enterprise
# 21  9.007199e+15          is_advertising
# ...

# %% [markdown]
# # **Building Model**

# %%
# We need to separate it first before train the data
X = df.drop(['labels'],axis=1)
y= df['labels']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=40)

# %%
df.tail()
# Out:
#      state_code   latitude   longitude  city  labels  age_first_funding_year  \
# 918           2  37.740594 -122.376471   174       1                  0.5178
# 919          12  42.504817  -71.195611    35       0                  7.2521
# 920           2  37.408261 -122.015920   191       0                  8.4959
# 921           2  37.556732 -122.288378   174       1                  0.7589
# 922           2  37.386778 -121.966277   181       1                  3.1205
#
#      age_last_funding_year  relationships  funding_rounds  funding_total_usd  \
# 918                 0.5178              9               1            1100000
# 919                 9.2274              1               3           52000000
# 920                 8.4959              5               1           44000000
# 921                 2.8329             12               2           15500000
# 922                 3.1205              4               1           20000000
#
# ...

# %% [markdown]
# # **Feature Scaling**

# %%
print(X_train.dtypes)
print()
print(y_train.dtypes)
print(y_train)
# Out:
# state_code                  int64
# latitude                  float64
# longitude                 float64
# city                        int64
# age_first_funding_year    float64
# age_last_funding_year     float64
# relationships               int64
# funding_rounds              int64
# funding_total_usd           int64
# milestones                  int64
# is_CA                       int64
# is_NY                       int64
# is_MA                       int64
# is_TX                       int64
# is_otherstate               int64
# category_code               int64
# is_software                 int64
# is_web                      int64
# is_mobile                   int64
# is_enterprise               int64
# is_advertising              int64
# is_gamesvideo               int64
# is_ecommerce                int64
# is_biotech                  int64
# is_consulting               int64
# is_othercategory            int64
# has_VC                      int64
# ...

# %%
print(X_train.dtypes)
print()
print(y_train.dtypes)
print(y_train)
# Out:
# state_code                  int64
# latitude                  float64
# longitude                 float64
# city                        int64
# age_first_funding_year    float64
# age_last_funding_year     float64
# relationships               int64
# funding_rounds              int64
# funding_total_usd           int64
# milestones                  int64
# is_CA                       int64
# is_NY                       int64
# is_MA                       int64
# is_TX                       int64
# is_otherstate               int64
# category_code               int64
# is_software                 int64
# is_web                      int64
# is_mobile                   int64
# is_enterprise               int64
# is_advertising              int64
# is_gamesvideo               int64
# is_ecommerce                int64
# is_biotech                  int64
# is_consulting               int64
# is_othercategory            int64
# has_VC                      int64
# ...

# %%
X_test = X_test[X_train.columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
model1 = lr.fit(X_train, y_train)
prediction1 = model1.predict(X_test)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,prediction1)
cm
# Out:
# array([[  0,  88],
#        [  0, 183]])

# %%
sns.heatmap(cm,annot=True)
plt.savefig('h.png')

# %%
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
print('Testing Accuracy:',(TP+TN)/(TP+TN+FN+FP))
# Out:
# Testing Accuracy: 0.6752767527675276

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction1)
# Out:
# 0.6752767527675276

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier()
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm2
# Out:
# array([[ 88,   0],
#        [  0, 183]])

# %%
accuracy_score(y_test,prediction2)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,prediction2)
# Out:
# 1.0

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier()
model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
confusion_matrix(y_test, prediction3)
# Out:
# array([[ 88,   0],
#        [  0, 183]])

# %%
accuracy_score(y_test, prediction3)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, prediction3))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        88
#            1       1.00      1.00      1.00       183
#
#     accuracy                           1.00       271
#    macro avg       1.00      1.00      1.00       271
# weighted avg       1.00      1.00      1.00       271

# %%
print(classification_report(y_test, prediction1))

print(classification_report(y_test, prediction2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        88
#            1       0.68      1.00      0.81       183
#
#     accuracy                           0.68       271
#    macro avg       0.34      0.50      0.40       271
# weighted avg       0.46      0.68      0.54       271
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        88
#            1       1.00      1.00      1.00       183
#
#     accuracy                           1.00       271
#    macro avg       1.00      1.00      1.00       271
# weighted avg       1.00      1.00      1.00       271

# %% [markdown]
# **K Nearest Neighbor (K NN) Support Vector Machine Naive Bayes**

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
models=[]

models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# evaluate each model

results =[]
names=[]
for name , model in models:
    kfold=KFold(n_splits=10, shuffle=True, random_state=40)
    cv_results= cross_val_score(model, X_train, y_train, cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    
    msg= '%s:, %f, (%f)' % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# KNN:, 0.636905, (0.055079)
# NB:, 0.630704, (0.053382)
# SVM:, 0.619593, (0.037388)

# %%
# make predictions on validation datasets

SVM = SVC()
SVM.fit(X_train, y_train)
predictions= SVM.predict(X_test)
print(accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 0.6752767527675276
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        88
#            1       0.68      1.00      0.81       183
#
#     accuracy                           0.68       271
#    macro avg       0.34      0.50      0.40       271
# weighted avg       0.46      0.68      0.54       271
#
# [[  0  88]
#  [  0 183]]
